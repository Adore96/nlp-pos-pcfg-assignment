# %%
import nltk
nltk.download('treebank')  # one-time; skips if already downloaded
from  nltk.corpus import treebank
# Out:
# [nltk_data] Downloading package treebank to
# [nltk_data]     C:\Users\kasun\AppData\Roaming\nltk_data...
# [nltk_data]   Package treebank is already up-to-date!

# %%
tagged_sents = treebank.tagged_sents()
parsed_sents = treebank.parsed_sents()
words = treebank.words()

print(f"Tagged sentences: {len(tagged_sents)}")
print(f"Parsed sentences: {len(parsed_sents)}")
print(f"Total tokens: {len(words)}")
# Out:
# Tagged sentences: 3914
# Parsed sentences: 3914
# Total tokens: 100676

# %%
tags = sorted({tag for sent in tagged_sents for word, tag in sent})
print(f"Unique tags: {len(tags)}")
print(tags)
# Out:
# Unique tags: 46
# ['#', '$', "''", ',', '-LRB-', '-NONE-', '-RRB-', '.', ':', 'CC', 'CD', 'DT', 'EX', 'FW', 'IN', 'JJ', 'JJR', 'JJS', 'LS', 'MD', 'NN', 'NNP', 'NNPS', 'NNS', 'PDT', 'POS', 'PRP', 'PRP$', 'RB', 'RBR', 'RBS', 'RP', 'SYM', 'TO', 'UH', 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ', 'WDT', 'WP', 'WP$', 'WRB', '``']

# %%
examples = [w for sent in tagged_sents[:50] for w, t in sent if t == '-NONE-'] #Daily Mirror sentences will never have these, so they need stripping before training
print(examples[:15])
# Out:
# ['*-1', '*', '*', '*', '0', '*T*-1', '*T*-1', '0', '*T*-2', '*T*-2', '*-2', '*', '*T*-3', '*T*-1', '0']

# %%
print(tagged_sents[0])
parsed_sents[0].pretty_print()
# Out:
# [('Pierre', 'NNP'), ('Vinken', 'NNP'), (',', ','), ('61', 'CD'), ('years', 'NNS'), ('old', 'JJ'), (',', ','), ('will', 'MD'), ('join', 'VB'), ('the', 'DT'), ('board', 'NN'), ('as', 'IN'), ('a', 'DT'), ('nonexecutive', 'JJ'), ('director', 'NN'), ('Nov.', 'NNP'), ('29', 'CD'), ('.', '.')]
#                                                      S
#                          ____________________________|_______________________________________________________________________
#                         |                                               VP                                                   |
#                         |                        _______________________|___                                                 |
#                       NP-SBJ                    |                           VP                                               |
#          _______________|___________________    |     ______________________|______________________________________          |
# ...

# %%
import sys
sys.path.insert(0, '..')
from src.data_utils import load_clean_treebank

clean_tagged_sents = load_clean_treebank()
